# %%
import pandas as pd
countries = pd.read_csv('https://raw.githubusercontent.com/ernbilen/Data200_Fall23/main/data/countries.csv')

# %%
countries
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# ...           ...       ...   ...             ...         ...           ...
# 1699     Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700     Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701     Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702     Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703     Zimbabwe    Africa  2007          43.487    12311143    469.709298
#
# [1704 rows x 6 columns]

# %%
# unique()
countries.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
# value_counts()
countries.country.value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
countries.continent.value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
# get the same freq table, but only for unique countries
# hint: consider dropping duplicates in "a column"
countries.drop_duplicates(subset=["country"]).continent.value_counts()
# Out:
# Africa      52
# Asia        33
# Europe      30
# Americas    25
# Oceania      2
# Name: continent, dtype: int64

# %%
# to get relative freq
countries.continent.value_counts(normalize=True)
# Out:
# Africa      0.366197
# Asia        0.232394
# Europe      0.211268
# Americas    0.176056
# Oceania     0.014085
# Name: continent, dtype: float64

# %%
import matplotlib.pyplot as plt
parks = pd.read_csv('https://raw.githubusercontent.com/ernbilen/Data200_Fall23/main/data/national_parks.csv')

# %%
parks
# Out:
#     Year  Badlands  GrandCanyon  BryceCanyon
# 0   1961    833300      1253000       264800
# 1   1962   1044800      1447400       251000
# 2   1963   1074000      1539500       289500
# 3   1964   1079800      1576600       300300
# 4   1965   1091300      1689200       366800
# 5   1966   1094800      1806000       396600
# 6   1967   1188700      1804900       295000
# 7   1968   1194600      1986300       320800
# 8   1969   1221300      2192600       366900
# 9   1970   1303100      2258200       345900
# 10  1971   1282000      2402100       377800
# 11  1972   1274600      2698300       424830
# 12  1973   1387900      1909700       429700
# 13  1974   1205300      1888600       408800
# 14  1975   1153200      2625100       579200
# 15  1976   1210100      2791600       625600
# 16  1977   1305400      2627200       611500
# 17  1978   1234915      2748642       679260
# 18  1979    858000      2131716       558095
# 19  1980    952652      2304973       571541
# ...

# %%
import numpy as np
np.sqrt(parks.shape[0])
# Out:
# 7.54983443527075

# %%
plt.hist(parks.GrandCanyon,edgecolor='black',facecolor='springgreen',bins=7)

plt.ylim(0,30)

plt.xlabel('# of visitors in million people')
plt.ylabel('count')

plt.savefig('/users/bilene/desktop/grand-canyon.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
# scatterplot
plt.scatter(parks.Year,parks.GrandCanyon)

plt.xlabel('year')
plt.ylabel('# of visitors')

plt.show()

# %%
# line plot
plt.plot(parks.Year,parks.GrandCanyon)

plt.xlabel('year')
plt.ylabel('# of visitors')

plt.show()

# %%
# line plot
plt.plot(parks.Year,parks.GrandCanyon,label='GrandCanyon')
plt.plot(parks.Year,parks.BryceCanyon,label='BryceCanyon')
plt.plot(parks.Year,parks.Badlands,label='Badlands')

plt.xlabel('year')
plt.ylabel('# of visitors')

plt.legend()

plt.show()

# %%
# practice time:
# work on the countries data
# make two histograms on the same plot for lifeExpectancy, one for where year is 2007 and one for 1952
# use different colors for the histograms
# show legend
# set alpha=.75 for 2007, and alpha=.5 for 1952

# %%
plt.hist(countries[countries.year==1952].lifeExpectancy, alpha=.5, facecolor="blue", \
         edgecolor='black',bins=12, label="1952")
plt.hist(countries[countries.year==2007].lifeExpectancy, alpha=.75, facecolor="purple", \
         edgecolor='black',bins=12, label="2007")
plt.xlabel("life expectancy")
plt.ylabel("count")
plt.legend()
plt.show()
